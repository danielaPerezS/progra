# %% [markdown]
# <a href="https://colab.research.google.com/github/danielaPerezS/progra/blob/main/Ev3_Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import io

# %%
from google.colab import files

# %%
uploaded = files.upload ()
# Out:
#      <input type="file" id="files-0ccebbac-9c2c-4c7c-9913-a8e917d236d2" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-0ccebbac-9c2c-4c7c-9913-a8e917d236d2">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
DataFrame = pd.read_csv(io.StringIO(uploaded['titanic.csv'].decode('latin-1')))

# %%
DataFrame
# Out:
#       IdClase  Sobreviviente                                           Nombre  \
# 0           1              1                    Allen, Miss. Elisabeth Walton
# 1           1              1                   Allison, Master. Hudson Trevor
# 2           1              0                     Allison, Miss. Helen Loraine
# 3           1              0             Allison, Mr. Hudson Joshua Creighton
# 4           1              0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...       ...            ...                                              ...
# 1304        3              0                             Zabour, Miss. Hileni
# 1305        3              0                            Zabour, Miss. Thamine
# 1306        3              0                        Zakarian, Mr. Mapriededer
# 1307        3              0                              Zakarian, Mr. Ortin
# 1308        3              0                               Zimmerman, Mr. Leo
#
#       Genero     Edad  \
# ...

# %%
DataFrame.shape
# Out:
# (1309, 13)

# %%
print(len(DataFrame))
# Out:
# 1309

# %%
print(DataFrame.shape[1])
# Out:
# 13

# %% [markdown]
#  type of data

# %%
DataFrame.dtypes
# Out:
# IdClase                                                                     int64
# Sobreviviente                                                               int64
# Nombre                                                                     object
# Genero                                                                     object
# Edad                                                                      float64
# Número de hermanos, hermanas, hermanastros o hermanastras en el barco.      int64
# Número de padres e hijos en el barco.                                       int64
# Ticket                                                                     object
# Precio                                                                    float64
# Camarote                                                                   object
# Puerto                                                                     object
# ...

# %% [markdown]
# Primeras 5 filas de datatime

# %%
DataFrame.head()
# Out:
#    IdClase  Sobreviviente                                           Nombre  \
# 0        1              1                    Allen, Miss. Elisabeth Walton
# 1        1              1                   Allison, Master. Hudson Trevor
# 2        1              0                     Allison, Miss. Helen Loraine
# 3        1              0             Allison, Mr. Hudson Joshua Creighton
# 4        1              0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
#
#    Genero     Edad  \
# 0  female  29.0000
# 1    male   0.9167
# 2  female   2.0000
# 3    male  30.0000
# 4  female  25.0000
#
#    Número de hermanos, hermanas, hermanastros o hermanastras en el barco.  \
# 0                                                  0
# 1                                                  1
# 2                                                  1
# 3                                                  1
# 4                                                  1
#
# ...

# %% [markdown]
# ultimas 5 filas

# %%
DataFrame.tail()
# Out:
#       IdClase  Sobreviviente                     Nombre  Genero  Edad  \
# 1304        3              0       Zabour, Miss. Hileni  female  14.5
# 1305        3              0      Zabour, Miss. Thamine  female   NaN
# 1306        3              0  Zakarian, Mr. Mapriededer    male  26.5
# 1307        3              0        Zakarian, Mr. Ortin    male  27.0
# 1308        3              0         Zimmerman, Mr. Leo    male  29.0
#
#       Número de hermanos, hermanas, hermanastros o hermanastras en el barco.  \
# 1304                                                  1
# 1305                                                  1
# 1306                                                  0
# 1307                                                  0
# 1308                                                  0
#
#       Número de padres e hijos en el barco.  Ticket   Precio Camarote Puerto  \
# 1304                                      0    2665  14.4542      NaN      C
# ...

# %% [markdown]
# Especificar la columna Nombre

# %%
DataFrame[['Nombre', 'Edad']]
# Out:
#                                                Nombre     Edad
# 0                       Allen, Miss. Elisabeth Walton  29.0000
# 1                      Allison, Master. Hudson Trevor   0.9167
# 2                        Allison, Miss. Helen Loraine   2.0000
# 3                Allison, Mr. Hudson Joshua Creighton  30.0000
# 4     Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  25.0000
# ...                                               ...      ...
# 1304                             Zabour, Miss. Hileni  14.5000
# 1305                            Zabour, Miss. Thamine      NaN
# 1306                        Zakarian, Mr. Mapriededer  26.5000
# 1307                              Zakarian, Mr. Ortin  27.0000
# 1308                               Zimmerman, Mr. Leo  29.0000
#
# [1309 rows x 2 columns]

# %%
DataFrame['Nombre']
# Out:
# 0                         Allen, Miss. Elisabeth Walton
# 1                        Allison, Master. Hudson Trevor
# 2                          Allison, Miss. Helen Loraine
# 3                  Allison, Mr. Hudson Joshua Creighton
# 4       Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
#                              ...
# 1304                               Zabour, Miss. Hileni
# 1305                              Zabour, Miss. Thamine
# 1306                          Zakarian, Mr. Mapriededer
# 1307                                Zakarian, Mr. Ortin
# 1308                                 Zimmerman, Mr. Leo
# Name: Nombre, Length: 1309, dtype: object

# %%
DataFrame.Edad
# Out:
# 0       29.0000
# 1        0.9167
# 2        2.0000
# 3       30.0000
# 4       25.0000
#          ...
# 1304    14.5000
# 1305        NaN
# 1306    26.5000
# 1307    27.0000
# 1308    29.0000
# Name: Edad, Length: 1309, dtype: float64

# %%
DataFrame['Nombre']=DataFrame['Nombre'].str.upper()
DataFrame
# Out:
#       IdClase  Sobreviviente                                           Nombre  \
# 0           1              1                    ALLEN, MISS. ELISABETH WALTON
# 1           1              1                   ALLISON, MASTER. HUDSON TREVOR
# 2           1              0                     ALLISON, MISS. HELEN LORAINE
# 3           1              0             ALLISON, MR. HUDSON JOSHUA CREIGHTON
# 4           1              0  ALLISON, MRS. HUDSON J C (BESSIE WALDO DANIELS)
# ...       ...            ...                                              ...
# 1304        3              0                             ZABOUR, MISS. HILENI
# 1305        3              0                            ZABOUR, MISS. THAMINE
# 1306        3              0                        ZAKARIAN, MR. MAPRIEDEDER
# 1307        3              0                              ZAKARIAN, MR. ORTIN
# 1308        3              0                               ZIMMERMAN, MR. LEO
#
#       Genero     Edad  \
# ...
